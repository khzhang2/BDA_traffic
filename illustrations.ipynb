# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
g_t_base = pd.read_csv('./outputs/BDA/base_regression_g_t.csv')
pred_base = pd.read_csv('./outputs/BDA/base_regression_pred_result.csv')
g_t_bda = pd.read_csv('./outputs/BDA/bda_regression_g_t.csv')
pred_bda = pd.read_csv('./outputs/BDA/bda_regression_pred_result.csv')

# %%
plt.figure(figsize=[20, 4])
plt.plot(range(371), g_t_base[12:], label='Ground Truth')
plt.plot(range(371), pred_base[12:], label='Base Model')
# plt.figure()
# plt.plot(range(371), g_t_bda)
plt.plot(range(371), pred_bda, label='BDA')
plt.legend()

# %%
plt.plot(range(371), g_t_base[12:])
plt.plot(range(371), g_t_bda)
