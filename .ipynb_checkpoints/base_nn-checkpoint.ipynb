# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset, TensorDataset

import ipdb

import bda_utils

# %% [markdown]
# # Load and assemble data

# %%
_, Xt = bda_utils.load_data(if_weekday=1, if_interdet=1)
Xt, Xt_min, Xt_max = bda_utils.normalize2D(Xt)

# %%
for i in range(Xt.shape[1]):
    plt.figure(figsize=[20,4])
    plt.plot(Xt[:, i])

# %%
label_seq_len = 3
# batch_size = full batch
seq_len = 12
reduced_dim = 4
inp_dim = Xt.shape[1]
label_dim = Xt.shape[1]
hid_dim = 12
layers = 1
lamb = 3

hyper = {
    'inp_dim':inp_dim,
    'label_dim':label_dim,
    'label_seq_len':label_seq_len,
    'seq_len':seq_len,
    'reduced_dim':reduced_dim,
    'hid_dim':hid_dim,
    'layers':layers,
    'lamb':lamb}
hyper = pd.DataFrame(hyper, index=['Values'])

# %%
hyper
# Out:
#         inp_dim  label_dim  label_seq_len  seq_len  reduced_dim  hid_dim  \
# Values       10         10              3       12            4       12
#
#         layers  lamb
# Values       1     3

# %%
Xt_train, Yt_train = bda_utils.sliding_window(Xt, Xt, seq_len, 1)
day_train_t = 1
Xt_valid = Xt_train.copy()[int(96*day_train_t):, :]
Xt_train = Xt_train.copy()[:int(96*day_train_t), :]
Yt_valid = Yt_train.copy()[int(96*day_train_t):, :]
Yt_train = Yt_train.copy()[:int(96*day_train_t), :]

# %%
batch_size = 1960

train_x = Xt_train
train_y = Yt_train

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_x = torch.tensor(train_x, dtype=torch.float32).to(device)
train_y = torch.tensor(train_y, dtype=torch.float32).to(device)
Xt_valid = torch.tensor(Xt_valid, dtype=torch.float32).to(device)
Yt_valid = torch.tensor(Yt_valid, dtype=torch.float32).to(device)

print(train_x.shape)
print(train_y.shape)
print('\n')
print(Xt_valid.shape)
print(Yt_valid.shape)

train_dataset = TensorDataset(train_x, train_y)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=False)
train_iter = iter(train_loader)
# Out:
# torch.Size([96, 12, 10])
# torch.Size([96, 1, 10])
#
#
# torch.Size([756, 12, 10])
# torch.Size([756, 1, 10])

# %% [markdown]
# # Learn

# %%
# build model
from bda_utils import traff_net
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = traff_net(inp_dim, label_dim).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.01)
#scheduler =  torch.optim.lr_scheduler.StepLR(optimizer, 0.7)
train_loss_set = []
val_loss_set = []

det = 5  # which detector to visualize

# %%
# train
net.train()

epochs = 2000

for e in range(epochs):
    for i in range(len(train_loader)):
        try:
            data, label = train_iter.next()
        except:
            train_iter = iter(train_loader)
            data, label = train_iter.next()
        ipdb.set_trace()
        out = net(data)
#         print(out.shape)
#         print(label.shape)
        loss = criterion(out, bda_utils.get_class(label[:, 0, :]) )
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        val_out = net(Xt_valid)
#         print(val_out.shape)
#         print(Yt_valid.shape)
        val_loss = criterion(val_out, bda_utils.get_class(Yt_valid[:, 0, :]) )
        
        val_loss_set.append(val_loss.cpu().detach().numpy())
        train_loss_set.append(loss.cpu().detach().numpy())
        
    if e%200==0:
        fig = plt.figure(figsize=[16,4])
        ax1 = fig.add_subplot(111)
        ax1.plot(label[:, :, det].cpu().detach().numpy(), label='ground truth')
        ax1.plot(out[:, det].cpu().detach().numpy(), label='predict')
        ax1.legend()
        plt.show()
        print('Epoch No. %i success, loss: %.5f, val loss: %.5f'%(e, loss.cpu().detach().numpy(), val_loss.cpu().detach().numpy()))
# Out:
# > /var/folders/tz/xs0vg7cs1bjc55mm1r8c9b8c0000gn/T/ipykernel_4816/3205988666.py(14)<module>()
#      13         ipdb.set_trace()
# ---> 14         out = net(data)
#      15 #         print(out.shape)
#
# ipdb> n
# > /var/folders/tz/xs0vg7cs1bjc55mm1r8c9b8c0000gn/T/ipykernel_4816/3205988666.py(17)<module>()
#      16 #         print(label.shape)
# ---> 17         loss = criterion(out, bda_utils.get_class(label[:, 0, :]) )
#      18
#
# ipdb> bda_utils.get_class(label[:, 0, :])
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /var/folders/tz/xs0vg7cs1bjc55mm1r8c9b8c0000gn/T/ipykernel_4816/3205988666.py in <module>
#      15 #         print(out.shape)
#      16 #         print(label.shape)
# ---> 17         loss = criterion(out, bda_utils.get_class(label[:, 0, :]) )
#      18
#      19         optimizer.zero_grad()
#
# /var/folders/tz/xs0vg7cs1bjc55mm1r8c9b8c0000gn/T/ipykernel_4816/3205988666.py in <module>
#      15 #         print(out.shape)
#      16 #         print(label.shape)
# ---> 17         loss = criterion(out, bda_utils.get_class(label[:, 0, :]) )
#      18
#      19         optimizer.zero_grad()
#
# /opt/anaconda3/envs/tca_traff/lib/python3.8/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /opt/anaconda3/envs/tca_traff/lib/python3.8/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
# %debug
# Out:
# > /Users/kylezhang/Documents/GitHub/zkh.github.io/BDA_traffic/bda_utils.py(73)get_class()
#      71             v = v.detach().numpy()
#      72         else:
# ---> 73             v = v.cpu().detach().numpy()
#      74         v_cls = []
#      75         for i in v:
#
# ipdb> device.type=='cpu'
# True
# ipdb> v.detach().numpy()
# *** AttributeError: 'numpy.ndarray' object has no attribute 'detach'
# ipdb> q

# %%
fig = plt.figure(figsize = [16, 4])
ax1 = fig.add_subplot(121)
ax1.plot(train_loss_set)
ax2 = fig.add_subplot(122)
ax2.plot(val_loss_set)

# %% [markdown]
# # Evaluation

# %%
val_out = val_out.cpu().detach().numpy()
Yt_valid = Yt_valid.cpu().detach().numpy()

# %%
net.eval()
m = 0.1

nrmse_loss = bda_utils.nrmse_loss_func(val_out, Yt_valid[:, 0, :], m)
mape_loss = bda_utils.mape_loss_func(val_out, Yt_valid[:, 0, :], m)
smape_loss = bda_utils.smape_loss_func(val_out, Yt_valid[:, 0, :], m)
mae_loss = bda_utils.mae_loss_func(val_out, Yt_valid[:, 0, :], m)

print('NRMSE: %.5f'%nrmse_loss)
print('MAPE: %.5f'%mape_loss)
print('SMAPE: %.5f'%smape_loss)
print('MAE: %.5f'%mae_loss)
# Out:
# NRMSE: 0.08809
# MAPE: 0.14142
# SMAPE: 0.13043
# MAE: 0.06228

# %%
plt.figure(figsize=[16,4])
plt.plot(Yt_valid[:, 0, det], label='label')
plt.plot(val_out[:, det], label='predict')
plt.legend()

# %%
torch.save(net.state_dict(), './model/base_for_y_p.pth'%nrmse_loss)
